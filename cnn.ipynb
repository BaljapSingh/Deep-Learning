# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
import matplotlib.pyplot as plt
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
gray_scale = 255
x_train /= gray_scale
x_test /= gray_scale
print("Feature matrix:", x_train.shape)
print("Target matrix:", x_test.shape)
print("Feature matrix:", y_train.shape)
print("Target matrix:", y_test.shape)
model = Sequential([
Flatten(input_shape=(28, 28)),
Dense(256, activation='sigmoid'),
Dense(128, activation='sigmoid'),
Dense(10, activation='sigmoid'),
])
model.compile(optimizer='adam',
loss='sparse_categorical_crossentropy',
metrics=['accuracy'])
model.fit(x_train, y_train, epochs=50,
batch_size=2000,
validation_split=0.2)

results = model.evaluate(x_test, y_test, verbose = 0)
print('test loss, test acc:', results)
# Out:
# Feature matrix: (60000, 28, 28)
# Target matrix: (10000, 28, 28)
# Feature matrix: (60000,)
# Target matrix: (10000,)
# Epoch 1/50
# 24/24 [==============================] - 1s 35ms/step - loss: 2.1654 - accuracy: 0.3021 - val_loss: 1.8660 - val_accuracy: 0.5161
# Epoch 2/50
# 24/24 [==============================] - 1s 32ms/step - loss: 1.5719 - accuracy: 0.6610 - val_loss: 1.2374 - val_accuracy: 0.7651
# Epoch 3/50
# 24/24 [==============================] - 1s 41ms/step - loss: 1.0386 - accuracy: 0.7816 - val_loss: 0.8188 - val_accuracy: 0.8310
# Epoch 4/50
# 24/24 [==============================] - 1s 37ms/step - loss: 0.7254 - accuracy: 0.8412 - val_loss: 0.5909 - val_accuracy: 0.8727
# Epoch 5/50
# 24/24 [==============================] - 1s 37ms/step - loss: 0.5529 - accuracy: 0.8738 - val_loss: 0.4679 - val_accuracy: 0.8892
# Epoch 6/50
# 24/24 [==============================] - 1s 37ms/step - loss: 0.4544 - accuracy: 0.8906 - val_loss: 0.3963 - val_accuracy: 0.9033
# Epoch 7/50
# 24/24 [==============================] - 1s 37ms/step - loss: 0.3943 - accuracy: 0.9006 - val_loss: 0.3512 - val_accuracy: 0.9097
# Epoch 8/50
# 24/24 [==============================] - 1s 41ms/step - loss: 0.3541 - accuracy: 0.9076 - val_loss: 0.3212 - val_accuracy: 0.9144
# Epoch 9/50
# 24/24 [==============================] - 1s 36ms/step - loss: 0.3252 - accuracy: 0.9129 - val_loss: 0.2976 - val_accuracy: 0.9193
# Epoch 10/50
# 24/24 [==============================] - 1s 38ms/step - loss: 0.3030 - accuracy: 0.9170 - val_loss: 0.2800 - val_accuracy: 0.9239
# Epoch 11/50
# 24/24 [==============================] - 1s 37ms/step - loss: 0.2849 - accuracy: 0.9212 - val_loss: 0.2659 - val_accuracy: 0.9261
# Epoch 12/50
# 24/24 [==============================] - 1s 37ms/step - loss: 0.2697 - accuracy: 0.9250 - val_loss: 0.2539 - val_accuracy: 0.9287
# Epoch 13/50
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2564 - accuracy: 0.9280 - val_loss: 0.2433 - val_accuracy: 0.9309
# Epoch 14/50
# 24/24 [==============================] - 1s 34ms/step - loss: 0.2447 - accuracy: 0.9308 - val_loss: 0.2337 - val_accuracy: 0.9341
# Epoch 15/50
# 24/24 [==============================] - 1s 30ms/step - loss: 0.2341 - accuracy: 0.9341 - val_loss: 0.2256 - val_accuracy: 0.9361
# Epoch 16/50
# 24/24 [==============================] - 1s 31ms/step - loss: 0.2241 - accuracy: 0.9368 - val_loss: 0.2181 - val_accuracy: 0.9379
# Epoch 17/50
# 24/24 [==============================] - 1s 32ms/step - loss: 0.2154 - accuracy: 0.9388 - val_loss: 0.2099 - val_accuracy: 0.9398
# Epoch 18/50
# 24/24 [==============================] - 1s 35ms/step - loss: 0.2062 - accuracy: 0.9418 - val_loss: 0.2028 - val_accuracy: 0.9441
# Epoch 19/50
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1982 - accuracy: 0.9440 - val_loss: 0.1976 - val_accuracy: 0.9438
# Epoch 20/50
# 24/24 [==============================] - 1s 31ms/step - loss: 0.1905 - accuracy: 0.9455 - val_loss: 0.1903 - val_accuracy: 0.9474
# Epoch 21/50
# 24/24 [==============================] - 1s 29ms/step - loss: 0.1831 - accuracy: 0.9479 - val_loss: 0.1852 - val_accuracy: 0.9494
# Epoch 22/50
# 24/24 [==============================] - 1s 29ms/step - loss: 0.1763 - accuracy: 0.9499 - val_loss: 0.1798 - val_accuracy: 0.9511
# Epoch 23/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1701 - accuracy: 0.9516 - val_loss: 0.1746 - val_accuracy: 0.9513
# Epoch 24/50
# 24/24 [==============================] - 1s 32ms/step - loss: 0.1636 - accuracy: 0.9530 - val_loss: 0.1715 - val_accuracy: 0.9519
# Epoch 25/50
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1580 - accuracy: 0.9549 - val_loss: 0.1657 - val_accuracy: 0.9545
# Epoch 26/50
# 24/24 [==============================] - 1s 31ms/step - loss: 0.1525 - accuracy: 0.9566 - val_loss: 0.1617 - val_accuracy: 0.9549
# Epoch 27/50
# 24/24 [==============================] - 1s 30ms/step - loss: 0.1466 - accuracy: 0.9579 - val_loss: 0.1567 - val_accuracy: 0.9565
# Epoch 28/50
# 24/24 [==============================] - 1s 30ms/step - loss: 0.1414 - accuracy: 0.9595 - val_loss: 0.1538 - val_accuracy: 0.9567
# Epoch 29/50
# 24/24 [==============================] - 1s 29ms/step - loss: 0.1366 - accuracy: 0.9612 - val_loss: 0.1505 - val_accuracy: 0.9564
# Epoch 30/50
# 24/24 [==============================] - 1s 29ms/step - loss: 0.1319 - accuracy: 0.9622 - val_loss: 0.1467 - val_accuracy: 0.9579
# Epoch 31/50
# 24/24 [==============================] - 1s 29ms/step - loss: 0.1270 - accuracy: 0.9637 - val_loss: 0.1431 - val_accuracy: 0.9588
# Epoch 32/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1226 - accuracy: 0.9656 - val_loss: 0.1405 - val_accuracy: 0.9601
# Epoch 33/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1187 - accuracy: 0.9667 - val_loss: 0.1379 - val_accuracy: 0.9610
# Epoch 34/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1142 - accuracy: 0.9679 - val_loss: 0.1339 - val_accuracy: 0.9612
# Epoch 35/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1101 - accuracy: 0.9695 - val_loss: 0.1314 - val_accuracy: 0.9621
# Epoch 36/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1064 - accuracy: 0.9702 - val_loss: 0.1293 - val_accuracy: 0.9622
# Epoch 37/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1026 - accuracy: 0.9718 - val_loss: 0.1266 - val_accuracy: 0.9635
# Epoch 38/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0996 - accuracy: 0.9725 - val_loss: 0.1246 - val_accuracy: 0.9639
# Epoch 39/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0960 - accuracy: 0.9738 - val_loss: 0.1225 - val_accuracy: 0.9647
# Epoch 40/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0929 - accuracy: 0.9746 - val_loss: 0.1194 - val_accuracy: 0.9653
# Epoch 41/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0894 - accuracy: 0.9757 - val_loss: 0.1175 - val_accuracy: 0.9657
# Epoch 42/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0860 - accuracy: 0.9770 - val_loss: 0.1166 - val_accuracy: 0.9668
# Epoch 43/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0836 - accuracy: 0.9774 - val_loss: 0.1139 - val_accuracy: 0.9665
# Epoch 44/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0805 - accuracy: 0.9788 - val_loss: 0.1120 - val_accuracy: 0.9678
# Epoch 45/50
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0779 - accuracy: 0.9790 - val_loss: 0.1103 - val_accuracy: 0.9678
# Epoch 46/50
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0753 - accuracy: 0.9800 - val_loss: 0.1080 - val_accuracy: 0.9688
# Epoch 47/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0723 - accuracy: 0.9812 - val_loss: 0.1075 - val_accuracy: 0.9682
# Epoch 48/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0697 - accuracy: 0.9818 - val_loss: 0.1053 - val_accuracy: 0.9692
# Epoch 49/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0673 - accuracy: 0.9826 - val_loss: 0.1035 - val_accuracy: 0.9695
# Epoch 50/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0650 - accuracy: 0.9834 - val_loss: 0.1035 - val_accuracy: 0.9695
# test loss, test acc: [0.09588124603033066, 0.9713000059127808]
